# %% [markdown]
# <a href="https://colab.research.google.com/github/626170998/Notebooks/blob/master/dofaker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 挂载 Google Drive
from google.colab import drive
drive.mount('/content/drive') # 按提示授权即可[reference:2]

# 检查 GPU 是否可用
# !nvidia-smi

# 安装 DoFaker 所需的 Python 依赖
# !pip install onnxruntime-gpu insightface gradio moviepy==1.0.3 opencv-python-headless
# Out:
# Mounted at /content/drive
# /bin/bash: line 1: nvidia-smi: command not found
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 246.7/246.7 MB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 42.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 77.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 343.2/343.2 kB 19.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.6/23.6 MB 52.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.6
#     Uninstalling protobuf-5.29.6:
#       Successfully uninstalled protobuf-5.29.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
# 4. 进入 Google Drive 并克隆源码
# %cd /content/drive/MyDrive/
# !git clone https://github.com/justld/dofaker.git
# %cd dofaker
# Out:
# /content/drive/MyDrive
# Cloning into 'dofaker'...
# remote: Enumerating objects: 296, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 296 (delta 2), reused 6 (delta 2), pack-reused 277 (from 1)
# Receiving objects: 100% (296/296), 12.58 MiB | 11.50 MiB/s, done.
# Resolving deltas: 100% (141/141), done.
# /content/drive/MyDrive/dofaker

# %%
# 5. 创建模型目录
# !mkdir -p weights/models

# %%
# !wget -c -O weights/models/buffalo_l.zip https://github.com/justld/dofaker/releases/download/release/buffalo_l.zip
# !wget -c -O weights/models/inswapper_128.onnx https://github.com/justld/dofaker/releases/download/release/inswapper_128.onnx
# !wget -c -O weights/models/GFPGANv1.3.onnx https://github.com/justld/dofaker/releases/download/release/GFPGANv1.3.onnx
# !wget -c -O weights/models/bsrgan_4.onnx https://github.com/justld/dofaker/releases/download/release/bsrgan_4.onnx
# !wget -c -O weights/models/openpose_body.onnx https://github.com/justld/dofaker/releases/download/release/openpose_body.onnx
# !wget -c -O weights/models/pose_transfer.onnx https://github.com/justld/dofaker/releases/download/release/pose_transfer.onnx
# Out:
# --2026-09-24 14:05:37--  https://github.com/justld/dofaker/releases/download/release/buffalo_l.zip
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !unzip -o weights/models/buffalo_l.zip -d weights/models/buffalo_l/
# !rm weights/models/buffalo_l.zip # 删除压缩包节省空间
# Out:
# Archive:  weights/models/buffalo_l.zip
#   inflating: weights/models/buffalo_l/genderage.onnx
#   inflating: weights/models/buffalo_l/2d106det.onnx
#   inflating: weights/models/buffalo_l/det_10g.onnx
#   inflating: weights/models/buffalo_l/1k3d68.onnx
#   inflating: weights/models/buffalo_l/w600k_r50.onnx

# %%
# 2. 动态修改 web_ui.py，在 launch 中强制开启 share=True
# !sed -i 's/web_ui.launch(inbrowser=args.inbrowser, server_port=args.server_port)/web_ui.launch(inbrowser=args.inbrowser, server_port=args.server_port, share=True)/' web_ui.py

# %%
# 3. 启动 Web UI（不再需要 --share 参数）
# !python web_ui.py --server_port 7861
# Out:
# error: XDG_RUNTIME_DIR is invalid or not set in the environment.
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5208:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5208:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1342:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5208:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5731:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2721:(snd_pcm_open_noupdate) Unknown PCM default
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5208:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ...
